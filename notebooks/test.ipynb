# %%
from pathlib import Path
import joblib

# %%
df_global = joblib.load("../data/df_global.pkl")

# %%
df_global.head()
# Out:
#    asking_price_sek  land_area_sqm  living_area_sqm  number_rooms   latitude  \
# 0         3695000.0            0.0             82.0           4.0  55.611843
# 1         3095000.0            0.0            109.0           4.0  55.723007
# 2         2295000.0            0.0             54.0           2.0  59.381943
# 3         3675000.0            0.0            119.0           4.0  57.931110
# 4          295000.0            0.0             99.0           4.0  58.382830
#
#    longitude  month  municipality_Abborreberg  municipality_Ale kommun  \
# 0  12.982288     12                     False                    False
# 1  13.197303     12                     False                    False
# 2  17.973993     12                     False                    False
# 3  12.536900     12                     False                    False
# 4  13.419069     12                     False                    False
#
#    municipality_Alingsås kommun  ...  municipality_Örnsköldsviks kommun  \
# ...
