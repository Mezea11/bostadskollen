# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from pathlib import Path

# %%
df_global = joblib.load("../data/df_global.pkl")

df_global.nsmallest(5, "number_rooms")
# Out:
#     asking_price_sek  land_area_sqm  living_area_sqm  number_rooms   latitude  \
# 11         1895000.0            0.0             37.0           1.0  57.662434
# 14         1150000.0            0.0             32.5           1.0  63.836554
# 16         2295000.0            0.0             51.0           1.0  57.713760
# 38          790000.0            0.0             37.0           1.0  56.905030
# 42         2290000.0            0.0             39.0           1.0  57.711132
#
#     longitude  municipality_Abborreberg  municipality_Ale kommun  \
# 11  12.004921                     False                    False
# 14  20.238257                     False                    False
# 16  12.000472                     False                    False
# 38  12.492928                     False                    False
# 42  12.007482                     False                    False
#
#     municipality_Alingsås kommun  municipality_Alvesta kommun  ...  \
# 11                         False                        False  ...
# 14                         False                        False  ...
# 16                         False                        False  ...
# 38                         False                        False  ...
# 42                         False                        False  ...
#
#     municipality_Örnsköldsviks kommun  municipality_Öster  \
# 11                              False               False
# 14                              False               False
# 16                              False               False
# 38                              False               False
# 42                              False               False
#
#     municipality_Östersunds kommun  municipality_Österåkers kommun  \
# 11                           False                           False
# 14                           False                           False
# 16                           False                           False
# 38                           False                           False
# 42                           False                           False
#
#     municipality_Östhammars kommun  municipality_Östra Göinge kommun  \
# 11                           False                             False
# 14                           False                             False
# 16                           False                             False
# 38                           False                             False
# 42                           False                             False
#
#     municipality_Östra-Alvesta  typology_APARTMENT  typology_HOUSE  \
# 11                       False                True           False
# 14                       False                True           False
# 16                       False                True           False
# 38                       False                True           False
# 42                       False                True           False
#
#     typology_ROW_HOUSE
# 11               False
# 14               False
# 16               False
# 38               False
# 42               False
#
# [5 rows x 309 columns]
